# %%
import pandas as pd
import numpy as np

# %%
file_name = "../data/College Basketball Dataset.csv"

basketball = pd.read_csv(file_name)
basketball.head()
# Out:
#              TEAM CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  \
# 0  North Carolina  ACC  40  33  123.3   94.9   0.9531   52.6   48.1  15.4
# 1       Wisconsin  B10  40  36  129.1   93.6   0.9758   54.8   47.7  12.4
# 2        Michigan  B10  40  33  114.4   90.4   0.9375   53.9   47.7  14.0
# 3         Gonzaga  WCC  39  37  117.8   86.3   0.9728   56.6   41.1  16.2
# 4        Kentucky  SEC  40  29  117.2   96.2   0.9062   49.9   46.0  18.1
#
#    ...  FTRD  2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  POSTSEASON  SEED  YEAR
# 0  ...  30.4  53.9  44.6  32.7  36.2   71.7   8.6         2ND   1.0  2016
# 1  ...  22.4  54.8  44.7  36.5  37.5   59.3  11.3         2ND   1.0  2015
# 2  ...  30.0  54.7  46.8  35.2  33.2   65.9   6.9         2ND   3.0  2018
# 3  ...  26.9  56.3  40.0  38.2  29.0   71.5   7.7         2ND   1.0  2017
# 4  ...  36.8  50.0  44.9  33.2  32.2   65.9   3.9         2ND   8.0  2014
#
# [5 rows x 24 columns]

# %%
seed1 = basketball.loc[basketball['SEED'] == 1].reset_index(drop=True)

# %%
seed1
# Out:
#               TEAM CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  \
# 0   North Carolina  ACC  40  33  123.3   94.9   0.9531   52.6   48.1  15.4
# 1        Wisconsin  B10  40  36  129.1   93.6   0.9758   54.8   47.7  12.4
# 2          Gonzaga  WCC  39  37  117.8   86.3   0.9728   56.6   41.1  16.2
# 3             Duke  ACC  39  35  125.2   90.6   0.9764   56.6   46.5  16.3
# 4   North Carolina  ACC  39  33  121.0   91.5   0.9615   51.7   48.1  16.2
# 5        Villanova   BE  40  36  128.4   94.1   0.9725   59.5   48.5  15.0
# 6       Louisville   BE  40  35  115.9   84.5   0.9743   50.6   44.8  18.3
# 7         Virginia  ACC  37  29  119.9   91.0   0.9600   54.8   48.4  15.1
# 8           Kansas  B12  37  32  120.9   90.4   0.9662   55.7   45.1  17.8
# 9           Kansas  B12  36  31  121.5   94.5   0.9472   56.1   48.1  17.6
# 10          Oregon  P12  37  30  118.4   96.2   0.9163   52.3   48.9  16.1
# ...

# %%
seed1.to_csv('../data/CollegeBasketballDatasetSeed1.csv', index = False)
