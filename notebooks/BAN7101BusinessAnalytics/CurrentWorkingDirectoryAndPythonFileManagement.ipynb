# %% [markdown]
# ### load an Excel dataset to this Python programming environment

# %%
# import libraries

import pandas as pd
import numpy as np
import os

# %%
curr_dir = os.getcwd()

# %%
# current working directory is the location of this jupyter notebook on my hard drive. 
print(curr_dir)
# Out:
# C:\Users\ZXT3080\GitHub\PythonIntroAndDataModeling\notebooks\BAN7101BusinessAnalytics

# %%
### specify a dataset file path that is relevent to our current working directory. 
file_path = 'College Basketball Dataset-2019.csv'

### read the dataset using Python command
df = pd.read_csv(file_path)


### full path setting
f_path = 'C:/Users/ZXT3080/GitHub/PythonIntroAndDataModeling/notebooks/BAN7101BusinessAnalytics/College Basketball Dataset-2019.csv'

ddf = pd.read_csv(f_path)

# show dataframes
df, ddf
# Out:
# (                       TEAM  CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  \
#  0                   Gonzaga   WCC  37  33  123.4   89.9   0.9744   59.0
#  1                  Virginia   ACC  38  35  123.0   89.9   0.9736   55.2
#  2                      Duke   ACC  38  32  118.9   89.2   0.9646   53.6
#  3            North Carolina   ACC  36  29  120.1   91.4   0.9582   52.9
#  4                  Michigan   B10  37  30  114.6   85.6   0.9665   51.6
#  ..                      ...   ...  ..  ..    ...    ...      ...    ...
#  348              Alcorn St.  SWAC  27  10   89.0  112.6   0.0628   45.7
#  349           New Hampshire    AE  27   5   83.7  106.1   0.0613   44.0
#  350             Chicago St.   WAC  30   3   88.5  117.3   0.0380   44.2
#  351            Delaware St.  MEAC  29   6   84.3  112.2   0.0358   40.0
#  352  Maryland Eastern Shore  MEAC  30   7   85.7  114.4   0.0346   43.5
#
#       EFG_D   TOR  ...   FTR  FTRD  2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  \
# ...

# %%
### To find the relationship between the location folder of the data file and the current working directory, 
### you can start with the current working directory.

filePath = '../../data/College Basketball Dataset.csv'

dataframe = pd.read_csv(filePath)

dataframe
# Out:
#                     TEAM  CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D  \
# 0         North Carolina   ACC  40  33  123.3   94.9   0.9531   52.6   48.1
# 1              Wisconsin   B10  40  36  129.1   93.6   0.9758   54.8   47.7
# 2               Michigan   B10  40  33  114.4   90.4   0.9375   53.9   47.7
# 3                Gonzaga   WCC  39  37  117.8   86.3   0.9728   56.6   41.1
# 4               Kentucky   SEC  40  29  117.2   96.2   0.9062   49.9   46.0
# ...                  ...   ...  ..  ..    ...    ...      ...    ...    ...
# 2097        Michigan St.   B10  35  26  111.4   87.8   0.9392   50.6   44.5
# 2098             Arizona   P12  35  27  114.4   92.2   0.9229   52.5   46.6
# 2099              Oregon   P12  37  28  104.8   88.6   0.8728   49.3   46.4
# 2100            La Salle   A10  34  24  112.0   96.2   0.8516   51.9   49.3
# 2101  Florida Gulf Coast  ASun  35  24  103.4   96.3   0.6952   51.6   46.9
#
# ...

# %%
### if you want to specify the file path without knowing the relationship
### between current working directlry and dataset file location

filepath = 'C:/Users/ZXT3080/GitHub/PythonIntroAndDataModeling/data/College Basketball Dataset.csv'

dframe = pd.read_csv(filepath)

dframe
# Out:
#                     TEAM  CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D  \
# 0         North Carolina   ACC  40  33  123.3   94.9   0.9531   52.6   48.1
# 1              Wisconsin   B10  40  36  129.1   93.6   0.9758   54.8   47.7
# 2               Michigan   B10  40  33  114.4   90.4   0.9375   53.9   47.7
# 3                Gonzaga   WCC  39  37  117.8   86.3   0.9728   56.6   41.1
# 4               Kentucky   SEC  40  29  117.2   96.2   0.9062   49.9   46.0
# ...                  ...   ...  ..  ..    ...    ...      ...    ...    ...
# 2097        Michigan St.   B10  35  26  111.4   87.8   0.9392   50.6   44.5
# 2098             Arizona   P12  35  27  114.4   92.2   0.9229   52.5   46.6
# 2099              Oregon   P12  37  28  104.8   88.6   0.8728   49.3   46.4
# 2100            La Salle   A10  34  24  112.0   96.2   0.8516   51.9   49.3
# 2101  Florida Gulf Coast  ASun  35  24  103.4   96.3   0.6952   51.6   46.9
#
# ...

# %%
dframe.describe()
# Out:
#                  G            W        ADJOE        ADJDE      BARTHAG  \
# count  2102.000000  2102.000000  2102.000000  2102.000000  2102.000000
# mean     31.450048    16.145100   103.299191   103.299286     0.494082
# std       2.678937     6.641093     7.436838     6.632112     0.256843
# min      15.000000     0.000000    76.600000    84.000000     0.005000
# 25%      30.000000    11.000000    98.225000    98.500000     0.282650
# 50%      31.000000    16.000000   102.900000   103.300000     0.474600
# 75%      33.000000    21.000000   108.100000   107.900000     0.714275
# max      40.000000    38.000000   129.100000   124.000000     0.984200
#
#              EFG_O        EFG_D          TOR         TORD          ORB  ...  \
# count  2102.000000  2102.000000  2102.000000  2102.000000  2102.000000  ...
# mean     49.671503    49.871551    18.789343    18.717460    30.149334  ...
# std       3.157149     2.950618     2.093918     2.218793     4.104225  ...
# ...

# %%
write a statement about your findings.
then go next.
